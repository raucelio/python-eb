# %% [markdown]
# # <font color = red> - Series Temporais
#
# ## Passageiros Aéreos
# Documentação do PyDataset (adotada a partir da documentação R. Os exemplos exibidos estão em R)
#
# ### Descrição
# Os dados clássicos da companhia aérea Box & Jenkins. Total mensal de internacional
# passageiros de avião, 1949 a 1960.
#
# ### Nome do Data Frame
#     AirPassengers
#
# ### Formato
# Uma série temporal mensal, em milhares.
#
# ### Fonte
# Caixa, G. E. P., Jenkins, G. M. e Reinsel, G. C. (1976) _Sime Série de Análise,
# Previsão e controle. Terceira edição. Holden-Day. Série G.
#
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## <font color = red> - Importar Biblioteca Pandas e Pydataset
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/stable/ <br>
# https://pypi.org/project/pydataset/

# %%
import pandas as pd
from pydataset import data

# %% [markdown]
# ## <font color = red> - Criar o Data Frame AirPassengers

# %%
df = data('AirPassengers')

# %% [markdown]
# ## <font color = red>- Visualuzar o Data Frame AirPassengers

# %%
df
# Out:
#             time  AirPassengers
# 1    1949.000000            112
# 2    1949.083333            118
# 3    1949.166667            132
# 4    1949.250000            129
# 5    1949.333333            121
# 6    1949.416667            135
# 7    1949.500000            148
# 8    1949.583333            148
# 9    1949.666667            136
# 10   1949.750000            119
# 11   1949.833333            104
# 12   1949.916667            118
# 13   1950.000000            115
# 14   1950.083333            126
# 15   1950.166667            141
# 16   1950.250000            135
# 17   1950.333333            125
# 18   1950.416667            149
# 19   1950.500000            170
# 20   1950.583333            170
# 21   1950.666667            158
# 22   1950.750000            133
# 23   1950.833333            114
# 24   1950.916667            140
# 25   1951.000000            145
# 26   1951.083333            150
# 27   1951.166667            178
# 28   1951.250000            163
# ...

# %% [markdown]
# ## <font color = red> # `.head()`
#
# - É para dar uma prévia dos primeiros registros.<br>
# df.head() ===> Visualizar apenas os 5 primeiros registros. <br>
# df.head(xx) ===> Onde xx é a quantidade de primeiros registros que você quer visualizar. <br>
# df.head(-xx) == elimina a quantidade de registros determinada pelo xx, começando pelos últimos. <br>
#
# head ===> Cabeça
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html

# %%
df.head()
# Out:
#           time  AirPassengers
# 1  1949.000000            112
# 2  1949.083333            118
# 3  1949.166667            132
# 4  1949.250000            129
# 5  1949.333333            121

# %% [markdown]
# ## <font color = red># `.shape`
# VIsualizar a quantidade de linha e colunas do DataFrame
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html

# %%
df.shape
# Out:
# (144, 2)

# %% [markdown]
# ## <font color = red> # `.tail()`
#
# É para dar uma prévia dos últimos registros.<br>
# `.head()` ===> Visualizar apenas os 5 últimos registros. <br>
# `.head(xx)` ===> Onde xx é a quantidade últimos registros que se quer visualizar.<br>
# `.head(-xx)` ==> elimina a quantidade de linhas determinada pelo xx <br>
#
# tail ===> Calda
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.tail.html

# %%
df.tail(10)
# Out:
#             time  AirPassengers
# 135  1960.166667            419
# 136  1960.250000            461
# 137  1960.333333            472
# 138  1960.416667            535
# 139  1960.500000            622
# 140  1960.583333            606
# 141  1960.666667            508
# 142  1960.750000            461
# 143  1960.833333            390
# 144  1960.916667            432

# %% [markdown]
# ## <font color = red> # `.iloc[ : ]`
#
# Pode substituir o `.head()` e o `.tail()`<br>
#
# `.iloc[:xx]` ===> semelhanto ao `.head(xx)`
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.iloc.html

# %%
#df.iloc[:10]
df.head(10)
# Out:
#            time  AirPassengers
# 1   1949.000000            112
# 2   1949.083333            118
# 3   1949.166667            132
# 4   1949.250000            129
# 5   1949.333333            121
# 6   1949.416667            135
# 7   1949.500000            148
# 8   1949.583333            148
# 9   1949.666667            136
# 10  1949.750000            119

# %% [markdown]
# `.iloc[:-xx]` ===> semelhanto ao `.head(-xx)`

# %%
#df.iloc[:-10]
df.head(-10)
# Out:
#             time  AirPassengers
# 1    1949.000000            112
# 2    1949.083333            118
# 3    1949.166667            132
# 4    1949.250000            129
# 5    1949.333333            121
# 6    1949.416667            135
# 7    1949.500000            148
# 8    1949.583333            148
# 9    1949.666667            136
# 10   1949.750000            119
# 11   1949.833333            104
# 12   1949.916667            118
# 13   1950.000000            115
# 14   1950.083333            126
# 15   1950.166667            141
# 16   1950.250000            135
# 17   1950.333333            125
# 18   1950.416667            149
# 19   1950.500000            170
# 20   1950.583333            170
# 21   1950.666667            158
# 22   1950.750000            133
# 23   1950.833333            114
# 24   1950.916667            140
# 25   1951.000000            145
# 26   1951.083333            150
# 27   1951.166667            178
# 28   1951.250000            163
# ...

# %% [markdown]
# `.iloc[-xx:]` ===> semelhant ao `.tail(xx)`

# %%
#df.iloc[-10:]
df.tail(10)
# Out:
#             time  AirPassengers
# 135  1960.166667            419
# 136  1960.250000            461
# 137  1960.333333            472
# 138  1960.416667            535
# 139  1960.500000            622
# 140  1960.583333            606
# 141  1960.666667            508
# 142  1960.750000            461
# 143  1960.833333            390
# 144  1960.916667            432

# %% [markdown]
# `.iloc[xx:]` ==> `.tail(-xx)`

# %%
df.iloc[10:]
df.tail(-10)
# Out:
#             time  AirPassengers
# 11   1949.833333            104
# 12   1949.916667            118
# 13   1950.000000            115
# 14   1950.083333            126
# 15   1950.166667            141
# 16   1950.250000            135
# 17   1950.333333            125
# 18   1950.416667            149
# 19   1950.500000            170
# 20   1950.583333            170
# 21   1950.666667            158
# 22   1950.750000            133
# 23   1950.833333            114
# 24   1950.916667            140
# 25   1951.000000            145
# 26   1951.083333            150
# 27   1951.166667            178
# 28   1951.250000            163
# 29   1951.333333            172
# 30   1951.416667            178
# 31   1951.500000            199
# 32   1951.583333            199
# 33   1951.666667            184
# 34   1951.750000            162
# 35   1951.833333            146
# 36   1951.916667            166
# 37   1952.000000            171
# 38   1952.083333            180
# ...

# %% [markdown]
# `.iloc[xx:xx]` ==> Comando para fazer um slice

# %%
df.iloc[10:20]
# Out:
#            time  AirPassengers
# 11  1949.833333            104
# 12  1949.916667            118
# 13  1950.000000            115
# 14  1950.083333            126
# 15  1950.166667            141
# 16  1950.250000            135
# 17  1950.333333            125
# 18  1950.416667            149
# 19  1950.500000            170
# 20  1950.583333            170

# %% [markdown]
# ## <font color = red> # `.dtypes`
#
#
# Verificar a tipagem das variáveis <br>
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html

# %%
df.dtypes
# Out:
# time             float64
# AirPassengers      int64
# dtype: object

# %% [markdown]
# ## <font color = red> # `pd.date_range`
# Criar uma variável com o formato data.
#
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html

# %%
df['data'] = pd.date_range(start = "1949-01", periods = len(df.index), freq = "M").to_period()

# %%
df
# Out:
#             time  AirPassengers    data
# 1    1949.000000            112 1949-01
# 2    1949.083333            118 1949-02
# 3    1949.166667            132 1949-03
# 4    1949.250000            129 1949-04
# 5    1949.333333            121 1949-05
# 6    1949.416667            135 1949-06
# 7    1949.500000            148 1949-07
# 8    1949.583333            148 1949-08
# 9    1949.666667            136 1949-09
# 10   1949.750000            119 1949-10
# 11   1949.833333            104 1949-11
# 12   1949.916667            118 1949-12
# 13   1950.000000            115 1950-01
# 14   1950.083333            126 1950-02
# 15   1950.166667            141 1950-03
# 16   1950.250000            135 1950-04
# 17   1950.333333            125 1950-05
# 18   1950.416667            149 1950-06
# 19   1950.500000            170 1950-07
# 20   1950.583333            170 1950-08
# 21   1950.666667            158 1950-09
# 22   1950.750000            133 1950-10
# ...

# %%
df.dtypes
# Out:
# time             float64
# AirPassengers      int64
# data              object
# dtype: object

# %% [markdown]
# ## <font color = red> - Colocar a data como índice
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.Index.html

# %%
df.index = pd.date_range(start = "1949-01", periods = len(df.index), freq = "M").to_period()

# %%
df
# Out:
#                 time  AirPassengers    data
# 1949-01  1949.000000            112 1949-01
# 1949-02  1949.083333            118 1949-02
# 1949-03  1949.166667            132 1949-03
# 1949-04  1949.250000            129 1949-04
# 1949-05  1949.333333            121 1949-05
# 1949-06  1949.416667            135 1949-06
# 1949-07  1949.500000            148 1949-07
# 1949-08  1949.583333            148 1949-08
# 1949-09  1949.666667            136 1949-09
# 1949-10  1949.750000            119 1949-10
# 1949-11  1949.833333            104 1949-11
# 1949-12  1949.916667            118 1949-12
# 1950-01  1950.000000            115 1950-01
# 1950-02  1950.083333            126 1950-02
# 1950-03  1950.166667            141 1950-03
# 1950-04  1950.250000            135 1950-04
# 1950-05  1950.333333            125 1950-05
# 1950-06  1950.416667            149 1950-06
# 1950-07  1950.500000            170 1950-07
# 1950-08  1950.583333            170 1950-08
# ...

# %%
# Selecionar apenas os anos que se quer
df['1950']
# Out:
#                 time  AirPassengers    data
# 1950-01  1950.000000            115 1950-01
# 1950-02  1950.083333            126 1950-02
# 1950-03  1950.166667            141 1950-03
# 1950-04  1950.250000            135 1950-04
# 1950-05  1950.333333            125 1950-05
# 1950-06  1950.416667            149 1950-06
# 1950-07  1950.500000            170 1950-07
# 1950-08  1950.583333            170 1950-08
# 1950-09  1950.666667            158 1950-09
# 1950-10  1950.750000            133 1950-10
# 1950-11  1950.833333            114 1950-11
# 1950-12  1950.916667            140 1950-12

# %%
# Selecionar um intervalo
df['1950': '1952']
# Out:
#                 time  AirPassengers    data
# 1950-01  1950.000000            115 1950-01
# 1950-02  1950.083333            126 1950-02
# 1950-03  1950.166667            141 1950-03
# 1950-04  1950.250000            135 1950-04
# 1950-05  1950.333333            125 1950-05
# 1950-06  1950.416667            149 1950-06
# 1950-07  1950.500000            170 1950-07
# 1950-08  1950.583333            170 1950-08
# 1950-09  1950.666667            158 1950-09
# 1950-10  1950.750000            133 1950-10
# 1950-11  1950.833333            114 1950-11
# 1950-12  1950.916667            140 1950-12
# 1951-01  1951.000000            145 1951-01
# 1951-02  1951.083333            150 1951-02
# 1951-03  1951.166667            178 1951-03
# 1951-04  1951.250000            163 1951-04
# 1951-05  1951.333333            172 1951-05
# 1951-06  1951.416667            178 1951-06
# 1951-07  1951.500000            199 1951-07
# 1951-08  1951.583333            199 1951-08
# ...

# %% [markdown]
# ## <font color = red> - Tanformar o índice de datetime para timestamp
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.Timestamp.html
#
# ## <font color = red> # `datetime` vs `timestamp`
# A maior diferença entre datetime e timestamp é a seguinte:
#
# ##### <font color = red>datetime:<br>
#
#     - Representa uma data como no calendário e a hora como encontrado no relógio.
#
# #### <font color = red>timestamp:<br>
#
#     - Representa um ponto específico na linha do tempo e leva em consideração o fuso horário em questão (UTC). Por exemplo: quando foi 26/02/2015 16:40? depende, para mim é nesse momento, para o Japão foi a várias horas atrás, então basicamente o timestamp leva em consideração essas questões de fuso horário.
#     - Outro ponto é que geralmente quando se precisa rastrear alterações feitas em registros da base de dados, opta-se pelo uso do timestamp pois permite o detalhamento perante a linha do tempo real.

# %%
df.index = df.index.to_timestamp() #to_period() causes erros with decomposition methods

# %%
df
# Out:
#                    time  AirPassengers    data
# 1949-01-01  1949.000000            112 1949-01
# 1949-02-01  1949.083333            118 1949-02
# 1949-03-01  1949.166667            132 1949-03
# 1949-04-01  1949.250000            129 1949-04
# 1949-05-01  1949.333333            121 1949-05
# 1949-06-01  1949.416667            135 1949-06
# 1949-07-01  1949.500000            148 1949-07
# 1949-08-01  1949.583333            148 1949-08
# 1949-09-01  1949.666667            136 1949-09
# 1949-10-01  1949.750000            119 1949-10
# 1949-11-01  1949.833333            104 1949-11
# 1949-12-01  1949.916667            118 1949-12
# 1950-01-01  1950.000000            115 1950-01
# 1950-02-01  1950.083333            126 1950-02
# 1950-03-01  1950.166667            141 1950-03
# 1950-04-01  1950.250000            135 1950-04
# 1950-05-01  1950.333333            125 1950-05
# 1950-06-01  1950.416667            149 1950-06
# 1950-07-01  1950.500000            170 1950-07
# ...

# %% [markdown]
# ## <font color = red> # `.drop`
# - Apagar a coluna
#
# ##### Referência
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html

# %%
#Apagar colunas times e data
df = df.drop(['time', 'data'],axis = 1)

# %%
df.head()
# Out:
#             AirPassengers
# 1949-01-01            112
# 1949-02-01            118
# 1949-03-01            132
# 1949-04-01            129
# 1949-05-01            121

# %% [markdown]
# ## <font color = red> - Filtrar linha
#
# - Igual `==`

# %%
df[df['AirPassengers'] == 136]
# Out:
#             AirPassengers
# 1949-09-01            136

# %% [markdown]
# - Maior `>` ou Menor `<`

# %%
df[df['AirPassengers'] > 136]
# Out:
#             AirPassengers
# 1949-07-01            148
# 1949-08-01            148
# 1950-03-01            141
# 1950-06-01            149
# 1950-07-01            170
# 1950-08-01            170
# 1950-09-01            158
# 1950-12-01            140
# 1951-01-01            145
# 1951-02-01            150
# 1951-03-01            178
# 1951-04-01            163
# 1951-05-01            172
# 1951-06-01            178
# 1951-07-01            199
# 1951-08-01            199
# 1951-09-01            184
# 1951-10-01            162
# 1951-11-01            146
# 1951-12-01            166
# 1952-01-01            171
# 1952-02-01            180
# 1952-03-01            193
# 1952-04-01            181
# 1952-05-01            183
# 1952-06-01            218
# 1952-07-01            230
# 1952-08-01            242
# 1952-09-01            209
# 1952-10-01            191
# 1952-11-01            172
# 1952-12-01            194
# 1953-01-01            196
# 1953-02-01            196
# ...

# %% [markdown]
# - Maior e Igual `>=` ou Menor e Igual `<=`

# %%
df[df['AirPassengers'] >= 136]
# Out:
#             AirPassengers
# 1949-07-01            148
# 1949-08-01            148
# 1949-09-01            136
# 1950-03-01            141
# 1950-06-01            149
# 1950-07-01            170
# 1950-08-01            170
# 1950-09-01            158
# 1950-12-01            140
# 1951-01-01            145
# 1951-02-01            150
# 1951-03-01            178
# 1951-04-01            163
# 1951-05-01            172
# 1951-06-01            178
# 1951-07-01            199
# 1951-08-01            199
# 1951-09-01            184
# 1951-10-01            162
# 1951-11-01            146
# 1951-12-01            166
# 1952-01-01            171
# 1952-02-01            180
# 1952-03-01            193
# 1952-04-01            181
# 1952-05-01            183
# 1952-06-01            218
# 1952-07-01            230
# 1952-08-01            242
# 1952-09-01            209
# 1952-10-01            191
# 1952-11-01            172
# 1952-12-01            194
# 1953-01-01            196
# ...

# %%
# Somente os palores pares
df[df['AirPassengers'] % 2 == 0]
# Out:
#             AirPassengers
# 1949-01-01            112
# 1949-02-01            118
# 1949-03-01            132
# 1949-07-01            148
# 1949-08-01            148
# 1949-09-01            136
# 1949-11-01            104
# 1949-12-01            118
# 1950-02-01            126
# 1950-07-01            170
# 1950-08-01            170
# 1950-09-01            158
# 1950-11-01            114
# 1950-12-01            140
# 1951-02-01            150
# 1951-03-01            178
# 1951-05-01            172
# 1951-06-01            178
# 1951-09-01            184
# 1951-10-01            162
# 1951-11-01            146
# 1951-12-01            166
# 1952-02-01            180
# 1952-06-01            218
# 1952-07-01            230
# 1952-08-01            242
# 1952-11-01            172
# 1952-12-01            194
# 1953-01-01            196
# 1953-02-01            196
# 1953-03-01            236
# 1953-07-01            264
# 1953-08-01            272
# 1953-11-01            180
# ...

# %%
# Somente os palores impares
df[df['AirPassengers'] % 2 != 0]
# Out:
#             AirPassengers
# 1949-04-01            129
# 1949-05-01            121
# 1949-06-01            135
# 1949-10-01            119
# 1950-01-01            115
# 1950-03-01            141
# 1950-04-01            135
# 1950-05-01            125
# 1950-06-01            149
# 1950-10-01            133
# 1951-01-01            145
# 1951-04-01            163
# 1951-07-01            199
# 1951-08-01            199
# 1952-01-01            171
# 1952-03-01            193
# 1952-04-01            181
# 1952-05-01            183
# 1952-09-01            209
# 1952-10-01            191
# 1953-04-01            235
# 1953-05-01            229
# 1953-06-01            243
# 1953-09-01            237
# 1953-10-01            211
# 1953-12-01            201
# 1954-03-01            235
# 1954-04-01            227
# 1954-08-01            293
# 1954-09-01            259
# 1954-10-01            229
# 1954-11-01            203
# 1954-12-01            229
# 1955-02-01            233
# ...

# %% [markdown]
# ##  <font color = red> - Plotar Gráficos <br>
# - Importar biblioteca `Matplotlib`
#
# ##### Referência
# https://matplotlib.org/tutorials/introductory/sample_plots.html

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##  <font color = red> - Gráfico de Linha
#
# ##### Referência
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html

# %%
df.plot()
#plt.show()

# %% [markdown]
# - Colocar Título e Legenda nos eixos do gráfico

# %%
#Titulo do gráfico e label das variáveis
df.plot()
plt.xlabel('Ano')
plt.ylabel('Qt Passageiros')
plt.title('Air Passemgers')
plt.show()

# %% [markdown]
# - Alterar o tamanho do Gráfico

# %%
plt.rcParams["figure.figsize"] = [16,9]
df.plot()
plt.xlabel('Ano')
plt.ylabel('Qt Passageiros')
plt.title('Air Passemgers')
plt.show()

# %% [markdown]
# - Posição da legenda
#
# https://matplotlib.org/api/legend_api.html
#
# Location String	Location Code <br>
# 'best' ===> 0<br>
# 'upper right' ===> 1<br>
# 'upper left' ===> 2<br>
# 'lower left' ===> 3<br>
# 'lower right' ===> 4<br>
# 'right' ===> 5<br>
# 'center left' ===> 6<br>
# 'center right' ===> 7<br>
# 'lower center' ===>	8<br>
# 'upper center' ===> 9<br>
# 'center' ===> 10<br>

# %%
plt.rcParams["figure.figsize"] = [16,9]
df.plot()
plt.xlabel('Ano')
plt.ylabel('Qt Passageiros')
plt.title('Air Passemgers')
plt.legend(loc = 'center left')
plt.show()

# %% [markdown]
# - Mudar a cor do Gráfico de Linha

# %%
plt.rcParams["figure.figsize"] = [16,9]
df.plot(color = 'r')
plt.xlabel('Ano')
plt.ylabel('Qt Passageiros')
plt.title('Air Passemgers')
plt.show()

# %% [markdown]
# - Adicionar linhas grades no gráfico de linha

# %%
plt.rcParams["figure.figsize"] = [16,9]
df.plot(color = 'r')
plt.xlabel('Ano')
plt.ylabel('Qt Passageiros')
plt.title('Air Passemgers')
plt.grid(True)
plt.show()

# %% [markdown]
# ##  <font color = red> -  Histograma
#
# ##### Referência
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html

# %%
plt.hist(df['AirPassengers'])
plt.show()

# %% [markdown]
# - Alterar a quantidade de barras

# %%
plt.hist(df['AirPassengers'], bins = 20)
plt.show()

# %% [markdown]
# - Alterar a cor do Histograma

# %%
plt.hist(df['AirPassengers'], color = 'red', bins = 20)
plt.show()

# %% [markdown]
# - Adicionar linhas grades no histograma

# %%
plt.hist(df['AirPassengers'], color = 'red', bins = 20)
plt.grid(True)

# %% [markdown]
# ##  <font color = red> -  Boxplot
#
# ##### Referência
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.boxplot.html

# %%
df.boxplot()
plt.show()

# %% [markdown]
# ## <font color = red> - Melhorando os gráficos
# - Criar um gráfico em branco

# %%
'''
fig ===> Significa figura
axes ===> é convencionado como eixos
'''
fig, axes = plt.subplots() 
plt.show()

# %% [markdown]
# - Título no Gráfico
#
# ##### Referência
# https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.set_title.html
#
# #### `ax.set_title` ===> Coloca um Título no Gráfico
#
# ##### Referência
# https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.set_title.html
#
# - Customizando o Título
# #### `size`  ===> Mudar o tamanho
#
#
# #### `color`  ===> Muda a Cor
#
# ##### Especificar as Cores
#
# - a hex RGB or RGBA string (e.g., '#0F0F0F' or '#0F0F0F0F')
# - one of {'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'}
# - one of {'C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'}
# - one of {'tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan'} which are the Tableau Colors from the ‘T10’ categorical palette (which is the default color cycle).<br>
#
# ##### Paleta de cores RGB ou RGBA
# http://www.ufpa.br/dicas/htm/htm-cor1.htm <br>
# http://www.ufpa.br/dicas/htm/htm-cor2.htm <br>
# http://www.csro.com.br/outros/tabela_rgb.html
#
# #### `weight` ===> Muda o tipo da fonte
#
# ['normal' | 'bold' | 'heavy' | 'light' | 'ultrabold' | 'ultralight']
#
# #### `style` ===> Estilo da fonte
# [ 'normal' | 'italic' | 'oblique' ]

# %%
fig, axes = plt.subplots()
axes.set_title('Boxplot - Número de Passageiros')
plt.show()

# %%
# Mudar o tamanho do título 
fig, axes = plt.subplots()
axes.set_title('Boxplot - Número de Passageiros', size = 30)
plt.show()

# %% [markdown]
# # Especificar as Cores
#
# - a hex RGB or RGBA string (e.g., '#0F0F0F' or '#0F0F0F0F')
# - one of {'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'}
# - one of {'C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'}
# - one of {'tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan'} which are the Tableau Colors from the ‘T10’ categorical palette (which is the default color cycle).<br>
#
# ##### Paleta de cores RGB ou RGBA
# http://www.ufpa.br/dicas/htm/htm-cor1.htm <br>
# http://www.ufpa.br/dicas/htm/htm-cor2.htm <br>
# http://www.csro.com.br/outros/tabela_rgb.html

# %%
#Mudar a cor do título
fig, axes = plt.subplots()
axes.set_title('Boxplot - Número de Passageiros', size  = 30, color = '#006400')
plt.show()

# %%
#Mudar o tipo de fonte
    
'''
['normal' | 'bold' | 'heavy' | 'light' | 'ultrabold' | 'ultralight']
'''

fig, axes = plt.subplots() #cria uma figura em branco
axes.set_title('Boxplot - Número de Passageiros', size  = 30, color = '#006400', weight = 'bold')
plt.show()

# %%
#Mudar o tipo de fonte

# style or fontstyle	[ 'normal' | 'italic' | 'oblique' ]

fig, axes = plt.subplots() #cria uma figura em branco
axes.set_title('Boxplot - Número de Passageiros', size  = 30, color = '#006400', weight = 'bold', style = 'italic')
plt.show()

# %% [markdown]
# - Definir o Gráfico usar como exemplo o Boxplo

# %%
fig, axes = plt.subplots() #cria uma figura em branco
axes.set_title('Boxplot - Número de Passageiros', size  = 30, color = '#006400', weight = 'bold', style = 'italic')
axes.boxplot(df['AirPassengers'])
plt.show()

# %% [markdown]
# -  Colocar legenda no eixo y

# %%
#Colocar legenda no eixo y
fig1, axes = plt.subplots() #cria uma figura em branco
axes.set_title('Boxplot - Número de Passageiros', size  = 30, color = '#006400', weight = 'bold', style = 'italic')
axes.boxplot(df['AirPassengers'])
plt.ylabel('Quantidade de Passageiros', size = 20,weight = 'bold', style = 'italic')#Colocar legenda no boxplot
plt.show()

# %% [markdown]
#  - Colocar legenda no boxplot  ou quando tiver mais de um boxplot

# %%
#Colocar legenda no boxplot
fig1, axes = plt.subplots() #cria uma figura em branco
axes.set_title('Boxplot - Número de Passageiros', size  = 30, color = '#006400', weight = 'bold', style = 'italic')
axes.boxplot(df['AirPassengers'])
plt.ylabel('Quantidade de Passageiros', size = 20,weight = 'bold', style = 'italic')#Colocar legenda no boxplot
axes.set_xticklabels(['AirPassengers'], size = 20,weight = 'bold', style = 'italic')
#plt.xticks([1], ['AirPassengers'], size = 20,weight = 'bold', style = 'italic') #Outra maneira de colocar a legenda mais está é para quando tiver mais de um

plt.show()

# %% [markdown]
#  - Mudar o estilo do Boxplot destacando a Mediana

# %%
#Colocar legenda no boxplot
fig, axes = plt.subplots()
axes.set_title('Boxplot - Número de Passageiros', size  = 30, color = '#006400', weight = 'bold', style = 'italic')
axes.boxplot(df['AirPassengers'],1) # ===> mudar a Mediana
plt.ylabel('Quantidade de Passageiros', size = 20,weight = 'bold', style = 'italic')
axes.set_xticklabels(['AirPassengers'], size = 20,weight = 'bold', style = 'italic')
plt.show()

# %% [markdown]
# - Boxplot horizontal

# %%
fig, axes = plt.subplots()
axes.set_title('Boxplot - Número de Passageiros', size  = 30, color = '#006400', weight = 'bold', style = 'italic')
axes.boxplot(df['AirPassengers'], 0 , 'rs' ,0) # ===> mudar Para Horizontal
plt.xlabel('Quantidade de Passageiros', size = 20,weight = 'bold', style = 'italic') # Mudar de Ylabel para xlabel
axes.set_yticklabels(['AirPassengers'], size = 20,weight = 'bold', style = 'italic')
plt.show()

# %% [markdown]
# ## <font color = red> -  Plotar Gráficos sobrepostos

# %%
'''
Para ficar melho substituir a palavra axes por ax
'''

fig, ax = plt.subplots()
ax = fig.add_axes([0.1,0.1,0.8,0.8]) #Posição em que o gráfico vai ser plotado
ax.plot(df)
plt.show()

# %%
fig, ax = plt.subplots()
ax = fig.add_axes([0.1,0.1,0.8,0.8]) #Posição em que o gráfico vai ser plotado
ax.plot(df)
plt.show()

# %%
fig, ax = plt.subplots()

ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(df)

ax2 = fig.add_axes([0.2,0.5,0.3,0.3])
ax2.plot(df)

plt.show()

# %%
#Plotar dois Gráficos
fig, ax = plt.subplots()


ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(df)

ax2 = fig.add_axes([0.2,0.5,0.3,0.3])
ax2.boxplot(df['AirPassengers'])


plt.show()

# %%
#Plotar dois Gráficos
fig, ax = plt.subplots()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(df)
ax1.set_title('Gráfico de Linha - Número de Passageiros', size  = 30, color = '#000000', weight = 'bold', style = 'italic')

ax2 = fig.add_axes([0.2,0.5,0.3,0.3])
ax2.boxplot(df['AirPassengers'])
ax2.set_title('Boxplot - Número de Passageiros', size  = 15, color = '#006400', weight = 'bold', style = 'italic')

plt.show()

# %%
#Plotar dois Gráficos
fig, ax = plt.subplots()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(df)
ax1.set_title('Gráfico de Linha - Número de Passageiros', size  = 30, color = '#000000', weight = 'bold', style = 'italic')
ax1.set_xlabel('Ano', size  = 20, color = '#000000', weight = 'bold', style = 'italic')


ax2 = fig.add_axes([0.2,0.5,0.3,0.3])
ax2.boxplot(df['AirPassengers'])
ax2.set_title('Boxplot - Número de Passageiros', size  = 18, color = '#006400', weight = 'bold', style = 'italic')
ax2.set_xticklabels(['AirPassengers'], size  = 15, color = '#006400', weight = 'bold', style = 'italic')

plt.show()

# %% [markdown]
# ## <font color = red> -  Plotar Vários Gráficos (1 x 3)

# %%
# Plotar Vários Gráfiocos
fig, ax = plt.subplots(1, 3) #Mesmo Eixo (1 linha, 3 colunas)
#fig, ax = plt.subplots(1, 3, figsize=(15, 4)) #Alterar o tamanho da figura
ax[0].hist(df['AirPassengers'], 20)

ax[1].plot(df['AirPassengers'])

ax[2].boxplot(df['AirPassengers'])

plt.show()

# %%
# Plotar Vários Gráfiocos colocando título
fig, ax = plt.subplots(1, 3) #Mesmo Eixo (1 linha, 3 colunas)
#fig, ax = plt.subplots(1, 3,figsize=(15, 4))

ax[0].hist(df['AirPassengers'], 20)
ax[0].set_title('Histograma')

ax[1].plot(df['AirPassengers'])
ax[1].set_title('Gráfico de Linha')

ax[2].boxplot(df['AirPassengers'])
ax[2].set_title('Boxplot')


plt.show()

# %%
# Plotar Vários Gráfiocos colocando nome do eixo x
fig, ax = plt.subplots(1, 3) #Mesmo Eixo (1 linha, 3 colunas)
#fig, ax = plt.subplots(1, 3,figsize=(15, 4))
ax[0].hist(df['AirPassengers'], 20)
ax[0].set_title('Histograma')
ax[0].set_xlabel('AirPassengers')


ax[1].plot(df['AirPassengers'])
ax[1].set_title('Gráfico de Linha')
ax[1].set_xlabel('Ano')



ax[2].boxplot(df['AirPassengers'])
ax[2].set_title('Boxplot')
ax[2].set_xticklabels(['AirPassengers'])

plt.show()

# %% [markdown]
# ## <font color = red> -  Plotar Vários Gráficos (2 x 2)

# %%
fig, ax = plt.subplots(2,2)

#fig, ax = plt.subplots(2,2,figsize=(9, 4))

ax[0,0].hist(df['AirPassengers'], 20)

ax[0,1].plot(df['AirPassengers'])

ax[1,0].boxplot(df['AirPassengers'],0,'rs',0)

ax[1,1].boxplot(df['AirPassengers'])

plt.show()

# %%
fig, ax = plt.subplots(2,2)

#fig, ax = plt.subplots(2,2,figsize=(9, 4))

ax[0,0].hist(df['AirPassengers'], 20)
ax[0,0].set_title('Histograma')

ax[0,1].plot(df['AirPassengers'])
ax[0,1].set_title('Gráfico de Linha')

ax[1,0].boxplot(df['AirPassengers'],0,'rs',0)
ax[1,0].set_title('Boxplot Horizontal')

ax[1,1].boxplot(df['AirPassengers'])
ax[1,1].set_title('Boxplot')

plt.show()

# %%
fig, ax = plt.subplots(2,2)

#fig, ax = plt.subplots(2,2,figsize=(9, 4))

ax[0,0].hist(df['AirPassengers'], 20)
ax[0,0].set_title('Histograma')

ax[0,1].plot(df['AirPassengers'])
ax[0,1].set_title('Gráfico de Linha')

ax[1,0].boxplot(df['AirPassengers'],0,'rs',0)
ax[1,0].set_title('Boxplot Horizontal')

ax[1,1].boxplot(df['AirPassengers'])
ax[1,1].set_title('Boxplot')

plt.show()

# %% [markdown]
# ## <font color = red> # `.tight_layout()`
#  - Evita sobreposição de figuras
#
# ###### Referência
# https://matplotlib.org/users/tight_layout_guide.html

# %%
fig, ax = plt.subplots(2,2)

ax[0,0].hist(df['AirPassengers'], 20)
ax[0,1].plot(df['AirPassengers'])
ax[1,0].boxplot(df['AirPassengers'],0,'rs',0)
ax[1,1].boxplot(df['AirPassengers'])
plt.tight_layout() # Evita sobreposição

# %% [markdown]
# ## <font color = red># `savefig`
# - Salvar figura
#
# ##### Referência
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.savefig.html

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].hist(df['AirPassengers'], 20)
ax[0,1].plot(df['AirPassengers'])
ax[1,1].boxplot(df['AirPassengers'])
fig.savefig('C:\\Users\Erivelton\\Pictures\\estat_basica\\image.jpeg')

# %% [markdown]
# ## <font color = red># `style.use`
# - Mudar o estiplo do plor
# ##### Referência
# https://matplotlib.org/users/style_sheets.html

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].hist(df['AirPassengers'], 20)
ax[0,1].plot(df['AirPassengers'])
ax[1,1].boxplot(df['AirPassengers'])
#plt.style.use('dark_background')
plt.show()
